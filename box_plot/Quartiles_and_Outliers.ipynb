# %% [markdown]
# <a href="https://colab.research.google.com/github/learn-ai-python/Data_Analysis/blob/master/box_plot/Quartiles_and_Outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 QUARTILES & OUTLIERS (КВАРТИЛІ ТА ВИКИДИ)
#
# 📸 Instagram: @learn.ai.python

# %% [markdown]
# ### 📚 Імпорт бібліотек

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 📌 Рахуємо квартилі (quantiles)
#
# **Квартилі** позначаються як Q1 (нижній квартиль), Q2 (медіана) і Q3 (верхній квартиль). Нижній квартиль відповідає 25-му процентилю, а верхній квартиль відповідає 75-му процентилю, тому є поняття **міжквартильного розмаху**:
#
# $$ 𝐼𝑄𝑅=𝑄3−𝑄1 $$

# %%
# Дані
data = [47, 12, 85, 23, 56, 91, 34, 72, 18, 63]

# Рахуємо квантилі and IQR з використанням NumPy
q1 = np.percentile(data, 25)
q2 = np.percentile(data, 50)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print("Q1:", q1)
print("Q2 (Median):", q2)
print("Q3:", q3)
print("IQR:", iqr)
# Out:
# Q1: 25.75
# Q2 (Median): 51.5
# Q3: 69.75
# IQR: 44.0

# %%
sns.set_palette("pastel")

# Побудовуємо графік
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, color="#D8BFD8", showfliers=False)

# Додаємо квартильні лінії для візуалізації
plt.axhline(y=q1, color="orange", linestyle="--", label="Q1")
plt.axhline(y=q2, color="blue", linestyle="--", label="Q2 (Median)")
plt.axhline(y=q3, color="green", linestyle="--", label="Q3")

# Задаємо осі та заголовок
plt.xlabel("data")
plt.ylabel("values")
plt.title("Boxplot")

# Додаємо легенту
plt.legend()

# Будуємо графік
plt.show()

# %% [markdown]
# ### 📌 Побудова графіку (outliers)
# **Викиди** - у статистиці результат вимірювання, який виділяється із загальної вибірки.

# %%
# Генеруємо рандомні дані з викидами
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 100), np.random.normal(8, 1, 10)])

# Задаємо колір графіку
pastel_green_palette = sns.color_palette(["#a1e579"])

# Створюємо box plot
sns.set(style="white", palette=pastel_green_palette)
plt.figure(figsize=(7, 3))

sns.boxplot(x=data)

# Додаємо заголовок і мітки
plt.title("Boxplot with Outliers")
plt.xlabel("data")

# Виводимо графік на екран
plt.show()
