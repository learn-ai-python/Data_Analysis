# %% [markdown]
# <a href="https://colab.research.google.com/github/learn-ai-python/Data_Analysis/blob/master/box_plot/Box_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 BOX PLOT (КОРОБКОВИЙ ГРАФІК)
# 📸 Instagram: @learn.ai.python

# %% [markdown]
# ### 📚 Імпорт бібліотек

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 🌷 Зчитування набору даних

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 📈 Візуалізація за допомогою box plot

# %%
sns.boxplot(x=df["sepal_length"],  # цільова колонка
            palette=["#e0a6ff"],  # колір графіка
            showmeans=True)  # візуалізація середнього значення

plt.show()
